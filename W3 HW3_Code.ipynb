# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Problem 1 <br>
# ### 𝑓(𝑥) = 𝑥4 − 6𝑥2 + 4𝑥 + 18

# %%
def f(x):
    return x**4 - 6 * (x**2) + 4*x +18

def df(x):
    return 4*(x**3) - (12*x) + 4

# %% [markdown]
# ### (iii) Plot the function 𝑓 over 𝑥 ∈ [−2.5, 2.5]. How many local/global minima do you see? What are their approximate values? Can there be other local minima?
#
# The global minima has x value approximately -1.8, y value approximately 1.5.<br>
# The local minima has x value approximately 1.5, y value approximately 15.5. <br>
# There could be no other local minimas, becasue by defination of quartic function, there would be at most 2 strict local minimas, and it was shown in graph that all 3 critical points appears in range [-2.5,2.5].

# %%
x = np.linspace(-2.5, 2.5, 500)

y = f(x)

plt.figure(figsize=(10, 5))
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of f(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### (iv) Write your own code for 𝑆 steps of GD on this function (do not use built-in or third-party GD codes).

# %%
def gradient_descent(S, alpha, x):
    x_values = {} 
    for i in range(S):
        x = x - alpha * df(x)
        step = f'x{i + 1}'
        x_values[step] = x
    return x_values

# Test for(i) S=3 with alpha=0.1 and initial_x=1.0
S = 3
alpha = 0.1
initial_x = 1.0

final_x = gradient_descent(S, alpha, initial_x)
print("Final x value after", S, "steps of Gradient Descent:", final_x)

# Test for(ii) S=3 with alpha=0.1 and initial_x=1.0
S = 3
alpha = 0.1
initial_x = 0.0

final_x = gradient_descent(S, alpha, initial_x)
print("Final x value after", S, "steps of Gradient Descent:", final_x)
# Out:
# Final x value after 3 steps of Gradient Descent: {'x1': 1.4, 'x2': 1.5823999999999998, 'x3': 1.4963546415104}
# Final x value after 3 steps of Gradient Descent: {'x1': -0.4, 'x2': -1.2544, 'x3': -2.3701509259264}

# %% [markdown]
# ### (v) Repeat (i) and (ii) using your code with 𝑆 = 20 steps. Do you observe convergence in both cases?
#
# For case (i), it converges to about 1.53.
#
# For case(ii), although the value of GD for S=20 is close to that for S=3 which is about -2.38, the GD values between them are oscillating, which we cannot conclude the convergence of GD.

# %% [markdown]
# Case (i) , x_0 = 1

# %%
S = 20
alpha = 0.1
initial_x = 1.0

final_x = gradient_descent(S, alpha, initial_x)
print("Final x value after", S, "steps of Gradient Descent:", final_x)
# Out:
# Final x value after 20 steps of Gradient Descent: {'x1': 1.4, 'x2': 1.5823999999999998, 'x3': 1.4963546415104, 'x4': 1.5517987790722083, 'x5': 1.5192154133381854, 'x6': 1.5397248375543011, 'x7': 1.5272719930151006, 'x8': 1.5350171190625246, 'x9': 1.5302671077620147, 'x10': 1.5332063790044113, 'x11': 1.5313973698196879, 'x12': 1.5325145038473287, 'x13': 1.5318260511057153, 'x14': 1.5322508642835628, 'x15': 1.5319889371285826, 'x16': 1.5321505120475563, 'x17': 1.5320508711908891, 'x18': 1.532112329575238, 'x19': 1.5320744264173558, 'x20': 1.5320978040292623}

# %% [markdown]
# Case (i) , x_0 = 0

# %%
S = 20
alpha = 0.1
initial_x = 0.0

final_x = gradient_descent(S, alpha, initial_x)
print("Final x value after", S, "steps of Gradient Descent:", final_x)
# Out:
# Final x value after 20 steps of Gradient Descent: {'x1': -0.4, 'x2': -1.2544, 'x3': -2.3701509259264, 'x4': -0.28849348925106977, 'x5': -1.0250813249728175, 'x6': -2.2243201263455896, 'x7': -0.8914857533491816, 'x8': -2.077866460212338, 'x9': -1.3828067104246002, 'x10': -2.384518789546544, 'x11': -0.22265870431016221, 'x12': -0.8854336582795075, 'x13': -2.070284616055942, 'x14': -1.405265292488476, 'x15': -2.3815530420008457, 'x16': -0.2363445410729268, 'x17': -0.9146772268543001, 'x18': -2.1061897151968125, 'x19': -1.2963647580668578, 'x20': -2.380554142228462}

# %% [markdown]
# ### (vi) Now set the learning rate to 𝛼 = 0.01 and repeat (v). Explain why GD performs differently from (v).
#
# This is because with the smaller learning rate, each step are less significant for the change of f, so it need to has more steps to get the values in (v).

# %% [markdown]
# Case (i) , x_0 = 1

# %%
S = 20
alpha = 0.01
initial_x = 1.0

final_x = gradient_descent(S, alpha, initial_x)
print("Final x value after", S, "steps of Gradient Descent:", final_x)
# Out:
# Final x value after 20 steps of Gradient Descent: {'x1': 1.04, 'x2': 1.0798054400000001, 'x3': 1.119020840068549, 'x4': 1.1572534830439267, 'x5': 1.1941304973887767, 'x6': 1.229315454262303, 'x7': 1.262522837530415, 'x8': 1.2935289442241535, 'x9': 1.3221782260494936, 'x10': 1.3483847002782723, 'x11': 1.372128707840095, 'x12': 1.3934498428239785, 'x13': 1.4124372242060033, 'x14': 1.4292183920198969, 'x15': 1.4439480114680723, 'x16': 1.4567973253950453, 'x17': 1.4679449872507762, 'x18': 1.4775696023631308, 'x19': 1.4858440513255176, 'x20': 1.4929314867366945}

# %% [markdown]
# Case (i) , x_0 = 0

# %%
S = 20
alpha = 0.01
initial_x = 0.0

final_x = gradient_descent(S, alpha, initial_x)
print("Final x value after", S, "st(i) ps of Gradient Descent:", final_x)
# Out:
# Final x value after 20 st(i) ps of Gradient Descent: {'x1': -0.04, 'x2': -0.08479744, 'x3': -0.1349487430013408, 'x4': -0.1910442892180012, 'x5': -0.2536906951534041, 'x6': -0.3234804877103682, 'x7': -0.40094419114643426, 'x8': -0.4864793227884729, 'x9': -0.5802515921846035, 'x10': -0.6820671425672264, 'x11': -0.791222869032004, 'x12': -0.9063563283704102, 'x13': -1.025336878870371, 'x14': -1.1452591933707572, 'x15': -1.2626045652651865, 'x16': -1.3736048457479124, 'x17': -1.4747692568020896, 'x18': -1.5634399244753172, 'x19': -1.6381892906071331, 'x20': -1.6989180105534625}

# %% [markdown]
# # Problem 2
# ## The College.csv dataset contains admissions data for a sample of 777 universities. We want to predict the number of applications received (‘Apps’) using the other variables in the dataset.

# %%
df = pd.read_csv('W3_College.csv')

df['Private'][df['Private'] == 'Yes'] = 1
df['Private'][df['Private'] == 'No'] = 0

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
#  17  Grad.Rate    777 non-null    int64
# dtypes: float64(1), int64(16), object(1)
# ...

# %% [markdown]
# ### (i) Let the first 600 observations be the training set and the remaining 177 observations be the test set.

# %%
train_size = 600

train_set, test_set = df[:600], df[600:]

print("Training set size:", len(train_set))
print("Test set size:", len(test_set))

X_train = train_set.drop('Apps', axis=1)
y_train = train_set['Apps']

X_test = test_set.drop('Apps', axis=1)
y_test = test_set['Apps']

#train_set
# Out:
# Training set size: 600
# Test set size: 177

# %% [markdown]
# ### (ii) Fit the OLS regression on the training set, and report the test error obtained.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model_ols = LinearRegression().fit(X_train, y_train)

y_pred_ols = model_ols.predict(X_test)
test_error_ols = mean_squared_error(y_test, y_pred_ols)

print("OLS Regression Test error:", test_error_ols)
# Out:
# OLS Regression Test error: 1502077.4348215673

# %% [markdown]
# ### For the rest of the problem, let the penalization parameter vary on the 1000-point grid from 0.01 to 60.

# %% [markdown]
# ### (iii) Fit the LASSO regression on the training set, with the penalization parameter chosen by 20-fold cross-validation. Report the test error obtained.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_private = X_train['Private']
X_test_private = X_test['Private']

X_train_scaled = scaler.fit_transform(X_train.drop('Private', axis=1))
X_test_scaled = scaler.transform(X_test.drop('Private', axis=1))

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.drop('Private', axis=1).columns)
X_train_scaled['Private'] = X_train_private

X_test = X_test.reset_index(drop=True)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.drop('Private', axis=1).columns)
X_test_scaled['Private'] = X_test_private


X_train_scaled.info()
X_test_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Accept       600 non-null    float64
#  1   Enroll       600 non-null    float64
#  2   Top10perc    600 non-null    float64
#  3   Top25perc    600 non-null    float64
#  4   F.Undergrad  600 non-null    float64
#  5   P.Undergrad  600 non-null    float64
#  6   Outstate     600 non-null    float64
#  7   Room.Board   600 non-null    float64
#  8   Books        600 non-null    float64
#  9   Personal     600 non-null    float64
#  10  PhD          600 non-null    float64
#  11  Terminal     600 non-null    float64
#  12  S.F.Ratio    600 non-null    float64
#  13  perc.alumni  600 non-null    float64
#  14  Expend       600 non-null    float64
#  15  Grad.Rate    600 non-null    float64
#  16  Private      600 non-null    object
# dtypes: float64(16), object(1)
# memory usage: 79.8+ KB
# ...

# %%
from sklearn.linear_model import LassoCV

alphas_lasso = np.linspace(0.01, 60, 1000)

model_lasso = LassoCV(alphas = alphas_lasso, cv = 20).fit(X_train_scaled, y_train)

y_pred_lasso = model_lasso.predict(X_test_scaled)
test_error_lasso = mean_squared_error(y_test, y_pred_lasso)

print("LASSO Regression Test error:", test_error_lasso)
print("LASSO Regression Best alpha:", model_lasso.alpha_)
# Out:
# LASSO Regression Test error: 1502015.7723211464
# LASSO Regression Best alpha: 0.01

# %% [markdown]
# ### (iv) Fit the ridge regression on the training set, with the penalization parameter chosen by leaveone-out cross-validation. Report the test error obtained.

# %%
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import LeaveOneOut

ridge_alphas = np.linspace(0.01, 60, 1000)

model_ridge = RidgeCV(alphas=ridge_alphas, cv=LeaveOneOut().get_n_splits(X_train_scaled)).fit(X_train_scaled, y_train)

y_pred_ridge = model_ridge.predict(X_test_scaled)
test_error_ridge = mean_squared_error(y_test, y_pred_ridge)

print("Ridge Regression Test error:", test_error_ridge)
print("Ridge Regression Best alpha:", model_ridge.alpha_)
# Out:
# Ridge Regression Test error: 1501856.6405985851
# Ridge Regression Best alpha: 0.01

# %% [markdown]
# ### (v) Which of the three models do you prefer? Is there much difference among the test errors?<br>
#
# I would choose the Ridge model becasue it has the smallest test error.
#
# The LASSO and Ridge models have smaller error than than of the OLS model, which indicate a better performance.

# %%
print("Test Errors", "\n","OLS:", test_error_ols, "\n","LASSO:",test_error_lasso,  "\n","Ridge:",test_error_ridge)
# Out:
# Test Errors
#  OLS: 1502077.4348215673
#  LASSO: 1502015.7723211464
#  Ridge: 1501856.6405985851
